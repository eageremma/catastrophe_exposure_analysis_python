# %% [markdown]
# # Catastrophe Exposure Analysis\n\nThis notebook summarises the end-to-end catastrophe exposure workflow built in Python.

# %% [markdown]
# ## Workflow\n\n1. Generate simulated property exposure records.\n2. Add realistic data quality issues.\n3. Clean and validate records.\n4. Score risk.\n5. Aggregate exposure.\n6. Visualise portfolio concentration.

# %%
import pandas as pd\ndf = pd.read_csv('../data/processed/scored_property_exposure_15000.csv')\ndf.head()

# %%
df.groupby('region')['total_insured_value'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# ## Key outcome\n\nThis project identifies where insured values are concentrated and which combinations of region, occupancy, and hazard zone create the largest catastrophe exposure.
